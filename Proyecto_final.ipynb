# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd
import numpy as np
import re
import sys, getopt
import csv
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Primero debemos comprobar que la pagina en cuestion puede ser utilizada. Procedemos a imprimir sencillamente los elementos contenidos dentro de "team" en el url de origen.

# %%
# URL de la página 
url = "https://fbref.com/en/comps/Big5/Big-5-European-Leagues-Stats"
# Realizar una solicitud GET a la página
response = requests.get(url)
# Comprobar si la solicitud fue exitosa
if response.status_code == 200:
    # Parsear el contenido HTML de la página con Beautiful Soup
    soup = BeautifulSoup(response.text, 'html.parser')
    # Encontrar todos los elementos "tbody" en la página
    tbody_elements = soup.find_all('tbody')
    # Iterar a través de los elementos "tbody"
   
    for tbody in tbody_elements:
        # Encontrar todos los elementos "td" con el atributo "data-stat" igual a "team" dentro del "tbody"
        team_td_elements = tbody.find_all('td', attrs={"data-stat": ["team"]})
        
        # Iterar a través de los elementos "td" y obtener el texto de cada uno
        for td_element in team_td_elements:
            team_list = td_element.get_text(strip=True) # Obtener el texto del elemento sin espacios en blanco innecesarios
            print(team_list)   
else:
    print("La solicitud no fue exitosa. Código de estado:", response.status_code)
# Out:
# Leverkusen
# Real Madrid
# Milan
# Stuttgart
# Arsenal
# Tottenham
# Girona
# Bayern Munich
# Dortmund
# Inter
# Atlético Madrid
# Barcelona
# Manchester City
# Hoffenheim
# Monaco
# Liverpool
# Juventus
# Fiorentina
# RB Leipzig
# Aston Villa
# Nice
# Brighton
# Athletic Club
# Paris S-G
# Brest
# Napoli
# West Ham
# Wolfsburg
# Real Sociedad
# Newcastle Utd
# Atalanta
# Reims
# Lille
# Monza
# Marseille
# Frosinone
# Crystal Palace
# Lecce
# Manchester Utd
# Rayo Vallecano
# Betis
# Eint Frankfurt
# Freiburg
# Roma
# Rennes
# Chelsea
# Bologna
# Nantes
# Fulham
# Montpellier
# Toulouse
# Lazio
# Sassuolo
# Strasbourg
# Valencia
# Las Palmas
# Nott'ham Forest
# Le Havre
# Torino
# Getafe
# Osasuna
# Sevilla
# Genoa
# Hellas Verona
# Cádiz
# Wolves
# Heidenheim
# Lens
# Darmstadt 98
# Metz
# Mallorca
# Villarreal
# Alavés
# Brentford
# Everton
# Lorient
# M'Gladbach
# Union Berlin
# Werder Bremen
# Augsburg
# Celta Vigo
# Granada
# Udinese
# Bochum
# Luton Town
# Burnley
# Empoli
# Lyon
# Bournemouth
# Salernitana
# Almería
# Clermont Foot
# Mainz 05
# Cagliari
# Köln
# Sheffield Utd

# %%
#Ahora iremos creando la data correspondiente a cada stat.
#stat team
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
# Inicializar una lista para almacenar los nombres de los equipos
team_names = []
# Encontrar todos los elementos td con data-stat="team" dentro de tbody
team_elements = tbody.find_all('td', {'data-stat': 'team'})

# Extraer el texto de los elementos y agregarlo a la lista
for team_element in team_elements:
    team_names.append(team_element.text)

# %%
print(team_names)
# Out:
# [' Leverkusen', ' Real Madrid', ' Milan', ' Stuttgart', ' Arsenal', ' Tottenham', ' Girona', ' Bayern Munich', ' Dortmund', ' Inter', ' Atlético Madrid', ' Barcelona', ' Manchester City', ' Hoffenheim', ' Monaco', ' Liverpool', ' Juventus', ' Fiorentina', ' RB Leipzig', ' Aston Villa', ' Nice', ' Brighton', ' Athletic Club', ' Paris S-G', ' Brest', ' Napoli', ' West Ham', ' Wolfsburg', ' Real Sociedad', ' Newcastle Utd', ' Atalanta', ' Reims', ' Lille', ' Monza', ' Marseille', ' Frosinone', ' Crystal Palace', ' Lecce', ' Manchester Utd', ' Rayo Vallecano', ' Betis', ' Eint Frankfurt', ' Freiburg', ' Roma', ' Rennes', ' Chelsea', ' Bologna', ' Nantes', ' Fulham', ' Montpellier', ' Toulouse', ' Lazio', ' Sassuolo', ' Strasbourg', ' Valencia', ' Las Palmas', " Nott'ham Forest", ' Le Havre', ' Torino', ' Getafe', ' Osasuna', ' Sevilla', ' Genoa', ' Hellas Verona', ' Cádiz', ' Wolves', ' Heidenheim', ' Lens', ' Darmstadt 98', ' Metz', ' Mallorca', ' Villarreal', ' Alavés', ' Brentford', ' Everton', ' Lorient', " M'Gladbach", ' Union Berlin', ' Werder Bremen', ' Augsburg', ' Celta Vigo', ' Granada', ' Udinese', ' Bochum', ' Luton Town', ' Burnley', ' Empoli', ' Lyon', ' Bournemouth', ' Salernitana', ' Almería', ' Clermont Foot', ' Mainz 05', ' Cagliari', ' Köln', ' Sheffield Utd']

# %%
#stat country
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
country_names = []
team_elements = tbody.find_all('td', {'data-stat': 'country'})

for team_element in team_elements:
    country_names.append(team_element.text)

# %%
#stat rank
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
rank_data = []
team_elements = tbody.find_all('td', {'data-stat': 'rank'})

for team_element in team_elements:
    rank_data.append(team_element.text)

# %%
#stat games
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
games_data = []
team_elements = tbody.find_all('td', {'data-stat': 'games'})

for team_element in team_elements:
    games_data.append(team_element.text)

# %%
#stat wins
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
wins_data = []
team_elements = tbody.find_all('td', {'data-stat': 'wins'})

for team_element in team_elements:
    wins_data.append(team_element.text)

# %%
#stat draws
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
draws_data = []
team_elements = tbody.find_all('td', {'data-stat': 'ties'})

for team_element in team_elements:
    draws_data.append(team_element.text)

# %%
#stat losses
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
losses_data = []
team_elements = tbody.find_all('td', {'data-stat': 'losses'})

for team_element in team_elements:
    losses_data.append(team_element.text)

# %%
#stat goals_for
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
goals_for_data = []
team_elements = tbody.find_all('td', {'data-stat': 'goals_for'})

for team_element in team_elements:
    goals_for_data.append(team_element.text)

# %%
#stat goals_against
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
# Inicializar una lista para almacenar los nombres de los equipos
goals_against = []
# Encontrar todos los elementos td con data-stat="team" dentro de tbody
team_elements = tbody.find_all('td', {'data-stat': 'goals_against'})

# Extraer el texto de los elementos y agregarlo a la lista
for team_element in team_elements:
    goals_against.append(team_element.text)

# %%
#stat goals_diff
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
goals_diff = []
team_elements = tbody.find_all('td', {'data-stat': 'goal_diff'})

for team_element in team_elements:
    goals_diff.append(team_element.text)

# %%
#stat points
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
points_data = []
team_elements = tbody.find_all('td', {'data-stat': 'points'})

for team_element in team_elements:
    points_data.append(team_element.text)

# %%
#stat points/game
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
points_game_data = []
team_elements = tbody.find_all('td', {'data-stat': 'points_avg'})

for team_element in team_elements:
    points_game_data.append(team_element.text)

# %%
#stat expected_goals
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
expected_goals = []
team_elements = tbody.find_all('td', {'data-stat': 'xg_for'})

for team_element in team_elements:
    expected_goals.append(team_element.text)

# %%
#stat expected_goals_allowed
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
expected_goals_allowed = []
team_elements = tbody.find_all('td', {'data-stat': 'xg_against'})

for team_element in team_elements:
    expected_goals_allowed.append(team_element.text)

# %%
#stat expected_goals_difference
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
expected_goals_difference = []
team_elements = tbody.find_all('td', {'data-stat': 'xg_diff'})

for team_element in team_elements:
    expected_goals_difference.append(team_element.text)

# %%
#stat expected_goals_difference_90min
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
expected_goals_difference_90min = []
team_elements = tbody.find_all('td', {'data-stat': 'xg_diff_per90'})

for team_element in team_elements:
    expected_goals_difference_90min.append(team_element.text)

# %%
#stat last_five_games
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
last_five_games = []
team_elements = tbody.find_all('td', {'data-stat': 'last_5'})

for team_element in team_elements:
    last_five_games.append(team_element.text)

# %%
#stat attendance
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
attendance_data = []
team_elements = tbody.find_all('td', {'data-stat': 'attendance_per_g'})

for team_element in team_elements:
    attendance_data.append(team_element.text)

# %%
#stat team_top_scorer
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
team_top_scorer = []
team_elements = tbody.find_all('td', {'data-stat': 'top_team_scorers'})

for team_element in team_elements:
    team_top_scorer.append(team_element.text)

# %%
#stat team_goalkeeper
soup = BeautifulSoup(response.text, 'html.parser')
tbody = soup.find('tbody')
team_goalkeeper = []
team_elements = tbody.find_all('td', {'data-stat': 'top_keeper'})

for team_element in team_elements:
    team_goalkeeper.append(team_element.text)

# %% [raw]
# Ahora procederemos a crear un dataframe con toda la data extraida.

# %%
big5leagues_data = pd.DataFrame({'Equipo': team_names, 'Pais': country_names, 'Puesto en liga': rank_data, 'Partidos jugados': games_data, 'Victorias': wins_data, 'Empates': draws_data, 'Derrotas': losses_data, 'Goles a favor': goals_for_data, 'Goles en contra': goals_against, 'Diferencia de goles': goals_diff, 'Puntos en liga': points_data, 'Puntos por partido jugado': points_game_data, 'Goles esperados': expected_goals, 'Goles esperados permitidos': expected_goals_allowed, 'Diferencia de goles esperados': expected_goals_difference, 'Difencia de goles esperados en 90 min': expected_goals_difference_90min, 'Resultados últimos 5 partidos': last_five_games, 'Asistencia al estadio': attendance_data, 'Goleador del equipo': team_top_scorer, 'Portero': team_goalkeeper})

# %%
big5leagues_data
# Out:
#             Equipo     Pais Puesto en liga Partidos jugados Victorias Empates  \
# 0       Leverkusen   de GER              1                7         6       1
# 1      Real Madrid   es ESP              1                9         8       0
# 2            Milan   it ITA              1                8         7       0
# 3        Stuttgart   de GER              2                7         6       0
# 4          Arsenal  eng ENG              2                8         6       2
# ..             ...      ...            ...              ...       ...     ...
# 91   Clermont Foot   fr FRA             18                7         0       2
# 92        Mainz 05   de GER             17                7         0       2
# 93        Cagliari   it ITA             20                8         0       2
# 94            Köln   de GER             18                7         0       1
# 95   Sheffield Utd  eng ENG             20                8         0       1
#
#    Derrotas Goles a favor Goles en contra Diferencia de goles Puntos en liga  \
# 0         0            23               6                 +17             19
# 1         1            20               6                 +14             24
# 2         1            16               8                  +8             21
# 3         1            22               8                 +14             18
# 4         0            16               6                 +10             20
# ..      ...           ...             ...                 ...            ...
# 91        5             5              12                  -7              2
# 92        5             6              19                 -13              2
# 93        6             3              16                 -13              2
# 94        6             4              14                 -10              1
# 95        7             6              22                 -16              1
#
#    Puntos por partido jugado Goles esperados Goles esperados permitidos  \
# 0                       2.71            16.8                        7.2
# 1                       2.67            17.3                        9.1
# 2                       2.63            12.4                        7.4
# 3                       2.57            14.9                        6.7
# 4                       2.50            14.9                        6.5
# ..                       ...             ...                        ...
# 91                      0.29             7.8                       11.5
# 92                      0.29             6.7                       11.5
# 93                      0.25             7.2                       12.5
# 94                      0.14             7.3                       13.4
# 95                      0.13             6.1                       19.6
#
#    Diferencia de goles esperados Difencia de goles esperados en 90 min  \
# 0                           +9.5                                 +1.36
# 1                           +8.2                                 +0.92
# 2                           +5.0                                 +0.63
# 3                           +8.2                                 +1.18
# 4                           +8.3                                 +1.04
# ..                           ...                                   ...
# 91                          -3.7                                 -0.53
# 92                          -4.8                                 -0.69
# 93                          -5.3                                 -0.67
# 94                          -6.1                                 -0.87
# 95                         -13.5                                 -1.69
#
#    Resultados últimos 5 partidos Asistencia al estadio  \
# 0                      W D W W W                29,721
# 1                      W L W W W                68,180
# 2                      L W W W W
# 3                      W W W W W                53,325
# 4                      W W D W W                60,105
# ..                           ...                   ...
# 91                     L D L L D
# 92                     L L L L D                32,370
# 93                     D L L L L
# 94                     D L L L L                49,600
# 95                     D L L L L                31,195
#
#                       Goleador del equipo                     Portero
# 0                     Victor Boniface - 7              Lukáš Hrádecký
# 1                     Jude Bellingham - 8           Kepa Arrizabalaga
# 2   Olivier Giroud, Christian Pulisic - 4                Mike Maignan
# 3                    Serhou Guirassy - 13             Alexander Nübel
# 4                         Bukayo Saka - 4  David Raya, Aaron Ramsdale
# ..                                    ...                         ...
# 91                      Cheick Konaté - 2                   Mory Diaw
# 92   Lee Jae-sung, Ludovic Ajorque... - 1               Robin Zentner
# 93                               Zito - 2             Boris Radunović
# 94                        Davie Selke - 2              Marvin Schwäbe
# 95                      Gustavo Hamer - 2             Wes Foderingham
#
# [96 rows x 20 columns]

# %% [markdown]
# Ahora procederemos a limpiar la data, por ejemplo el Pais de los equipos y demás

# %%
#Vamos primero a renombrar las ligas de los paises
big5leagues_data.Pais.replace(["de GER","es ESP","it ITA","eng ENG","fr FRA"] , ["Alemania","España","Italia","Inglaterra","Francia"], inplace= True)

# %%
big5leagues_data
# Out:
#             Equipo        Pais Puesto en liga Partidos jugados Victorias  \
# 0       Leverkusen    Alemania              1                7         6
# 1      Real Madrid      España              1                9         8
# 2            Milan      Italia              1                8         7
# 3        Stuttgart    Alemania              2                7         6
# 4          Arsenal  Inglaterra              2                8         6
# ..             ...         ...            ...              ...       ...
# 91   Clermont Foot     Francia             18                7         0
# 92        Mainz 05    Alemania             17                7         0
# 93        Cagliari      Italia             20                8         0
# 94            Köln    Alemania             18                7         0
# 95   Sheffield Utd  Inglaterra             20                8         0
#
#    Empates Derrotas Goles a favor Goles en contra Diferencia de goles  \
# 0        1        0            23               6                 +17
# 1        0        1            20               6                 +14
# 2        0        1            16               8                  +8
# 3        0        1            22               8                 +14
# 4        2        0            16               6                 +10
# ..     ...      ...           ...             ...                 ...
# 91       2        5             5              12                  -7
# 92       2        5             6              19                 -13
# 93       2        6             3              16                 -13
# 94       1        6             4              14                 -10
# 95       1        7             6              22                 -16
#
#    Puntos en liga Puntos por partido jugado Goles esperados  \
# 0              19                      2.71            16.8
# 1              24                      2.67            17.3
# 2              21                      2.63            12.4
# 3              18                      2.57            14.9
# 4              20                      2.50            14.9
# ..            ...                       ...             ...
# 91              2                      0.29             7.8
# 92              2                      0.29             6.7
# 93              2                      0.25             7.2
# 94              1                      0.14             7.3
# 95              1                      0.13             6.1
#
#    Goles esperados permitidos Diferencia de goles esperados  \
# 0                         7.2                          +9.5
# 1                         9.1                          +8.2
# 2                         7.4                          +5.0
# 3                         6.7                          +8.2
# 4                         6.5                          +8.3
# ..                        ...                           ...
# 91                       11.5                          -3.7
# 92                       11.5                          -4.8
# 93                       12.5                          -5.3
# 94                       13.4                          -6.1
# 95                       19.6                         -13.5
#
#    Difencia de goles esperados en 90 min Resultados últimos 5 partidos  \
# 0                                  +1.36                     W D W W W
# 1                                  +0.92                     W L W W W
# 2                                  +0.63                     L W W W W
# 3                                  +1.18                     W W W W W
# 4                                  +1.04                     W W D W W
# ..                                   ...                           ...
# 91                                 -0.53                     L D L L D
# 92                                 -0.69                     L L L L D
# 93                                 -0.67                     D L L L L
# 94                                 -0.87                     D L L L L
# 95                                 -1.69                     D L L L L
#
#    Asistencia al estadio                    Goleador del equipo  \
# 0                 29,721                    Victor Boniface - 7
# 1                 68,180                    Jude Bellingham - 8
# 2                         Olivier Giroud, Christian Pulisic - 4
# 3                 53,325                   Serhou Guirassy - 13
# 4                 60,105                        Bukayo Saka - 4
# ..                   ...                                    ...
# 91                                            Cheick Konaté - 2
# 92                32,370   Lee Jae-sung, Ludovic Ajorque... - 1
# 93                                                     Zito - 2
# 94                49,600                        Davie Selke - 2
# 95                31,195                      Gustavo Hamer - 2
#
#                        Portero
# 0               Lukáš Hrádecký
# 1            Kepa Arrizabalaga
# 2                 Mike Maignan
# 3              Alexander Nübel
# 4   David Raya, Aaron Ramsdale
# ..                         ...
# 91                   Mory Diaw
# 92               Robin Zentner
# 93             Boris Radunović
# 94              Marvin Schwäbe
# 95             Wes Foderingham
#
# [96 rows x 20 columns]

# %%
#Comprobaremos que los datos para una determinada liga sean correctos
datos_liga=big5leagues_data[big5leagues_data['Pais'] == 'España'] [['Equipo','Puesto en liga','Puntos en liga']]
print(datos_liga)
# Out:
#               Equipo Puesto en liga Puntos en liga
# 1        Real Madrid              1             24
# 6             Girona              2             22
# 10   Atlético Madrid              4             19
# 11         Barcelona              3             21
# 22     Athletic Club              5             17
# 28     Real Sociedad              6             15
# 39    Rayo Vallecano              8             13
# 40             Betis              7             13
# 54          Valencia              9             11
# 55        Las Palmas             10             11
# 59            Getafe             11             10
# 60           Osasuna             12             10
# 61           Sevilla             14              8
# 64             Cádiz             13              9
# 70          Mallorca             15              8
# 71        Villarreal             16              8
# 72            Alavés             17              8
# 80        Celta Vigo             18              6
# 81           Granada             19              6
# 90           Almería             20              3
